# %%
import pandas as pd

dummy_data = [[1, 2, 3], [4, 5, 6]]
df = pd.DataFrame(data=dummy_data).T
print(df)
df["Suma"] = df.sum(axis = 1)
print(df)
# Out:
#    0  1
# 0  1  4
# 1  2  5
# 2  3  6
#    0  1  Suma
# 0  1  4     5
# 1  2  5     7
# 2  3  6     9
